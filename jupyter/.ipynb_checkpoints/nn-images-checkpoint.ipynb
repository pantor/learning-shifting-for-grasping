# %%
import os

os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

import tensorflow as tf

# %load_ext autoreload
# %autoreload 2

# %%
from generate_input_planar_pose import GenerateInputPlanarPose

directory = os.path.expanduser('~/Documents/data/')

generator = GenerateInputPlanarPose([
    directory + 'cylinder-2/cylinder-2.db',
], output_folder='gen-image/')

generator.generateInput({
    'did_grasp_weight': 0.13,
    'force_rewrite': True,
    'inpaint': False,
    'raw_images': True,
    'size_cropped': (200, 200),
    'size_input': (752, 480),
    'size_output': (32, 32),
})
# Out:
# Reward Mean: 0.485
# Written training data to /home/berscheid/Documents/data/cylinder-2/gen-image/train.csv
# Written test data to /home/berscheid/Documents/data/cylinder-2/gen-image/test.csv

# %%
from tensorflow_dual_loader import DataLoader

test_loader = DataLoader(generator.test_output_filename)
train_loader = DataLoader(generator.train_output_filename, batch_size=128)
# Out:
# Length: 184
# Reward Mean: 0.5489130434782609
# Length: 721
# Reward Mean: 0.46879334257975036

# %%
from tensorflow_utils import get_augmentation, single_class_split, tf_accuracy, tf_precision, tf_recall, tf_f1

tf.reset_default_graph()
# tf.set_random_seed(3)


train_dataset = tf.data.Dataset.from_generator(train_loader.nextBatch, (tf.float32, tf.float32, tf.float32), ((None, None, None, 1), (None, None, None, 1), (None, 3)))
# train_dataset = train_dataset.map(get_augmentation(flip_up_down=False, flip_left_right=False, height=False, noise=False, defects=False, blur=False), num_parallel_calls=4)

test_dataset = tf.data.Dataset.from_generator(test_loader.entireBatch, (tf.float32, tf.float32, tf.float32))


handle = tf.placeholder(tf.string, shape=(), name='handle')
iterator = tf.data.Iterator.from_string_handle(handle, train_dataset.output_types, train_dataset.output_shapes)
train_iterator = train_dataset.make_initializable_iterator()
test_iterator = test_dataset.make_initializable_iterator()
    
depth_image, raw_image, label = iterator.get_next()


def act(x): return tf.nn.leaky_relu(x, 0.1)
def reg(l1=0.0, l2=0.5): return tf.contrib.layers.l1_l2_regularizer(l1, l2)
    
    
training = tf.placeholder_with_default(False, (), name='training')
apply_dropout = tf.placeholder_with_default(training, (), name='apply_dropout')
depth_image = tf.identity(depth_image, name='depth_image')
raw_image = tf.identity(raw_image, name='raw_image')
label = tf.identity(label, name='label')


x = depth_image # tf.concat([depth_image, raw_image], axis=3)
x = tf.image.random_flip_up_down(x)
x = tf.image.random_flip_up_down(x)
 
x = tf.layers.conv2d(x, 32, (5, 5), strides=(2, 2), activation=act, kernel_regularizer=reg(), bias_regularizer=reg())
x = tf.layers.batch_normalization(x, training=training)
# x = tf.layers.dropout(x, 0.2, training=apply_dropout)
    
x = tf.layers.conv2d(x, 48, (5, 5), strides=(1, 1), dilation_rate=(1, 1), activation=act, kernel_regularizer=reg(), bias_regularizer=reg())
x = tf.layers.batch_normalization(x, training=training)
x = tf.layers.dropout(x, 0.4, training=apply_dropout)

x = tf.layers.conv2d(x, 64, (5, 5), dilation_rate=(1, 1), activation=act, kernel_regularizer=reg(), bias_regularizer=reg())
x = tf.layers.batch_normalization(x, training=training)
x = tf.layers.dropout(x, 0.4, training=apply_dropout)

x = tf.layers.conv2d(x, 142, (6, 6), dilation_rate=(1, 1), activation=act, kernel_regularizer=reg(), bias_regularizer=reg())
# x = tf.layers.batch_normalization(x, training=training)
x = tf.layers.dropout(x, 0.4, training=apply_dropout)
    
x = tf.layers.conv2d(x, 128, (1, 1), dilation_rate=(1, 1), activation=act, kernel_regularizer=reg(), bias_regularizer=reg())
x = tf.layers.dropout(x, 0.3, training=apply_dropout)
    
logits = tf.layers.conv2d(x, 3, (1, 1), dilation_rate=(1, 1), bias_regularizer=reg(l2=0.3))
prob = tf.nn.sigmoid(logits, name='prob')
# var_prob = tf.expand_dims(tf.abs(tf.reduce_mean(tf.reduce_mean(tf.gradients(prob, [x_depth])[0], axis=2, keepdims=True), axis=1, keepdims=True)), 3, name='var_prob')

    
reward, reward_pred = single_class_split(label, prob[:, 0, 0])
_, logits_pred = single_class_split(label, logits[:, 0, 0])

weights = tf.abs(0.6 - reward) # 1.0 or tf.abs(0.75 - reward) or label[:, 2]
loss = tf.losses.sigmoid_cross_entropy(multi_class_labels=reward, logits=logits_pred, weights=weights)
loss_reg = loss + tf.add_n(tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES))
    
accuracy = tf_accuracy(reward, reward_pred)
precision = tf_precision(reward, reward_pred)
recall = tf_recall(reward, reward_pred)
f1 = tf_f1(precision, recall, beta=0.5)

extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)  # For batch normalization layers
with tf.control_dependencies(extra_update_ops):
    train = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(loss_reg, name='train')

# %%
from tensorflow_model import Model

model = Model(
    test_metrices=[loss, accuracy, precision, recall, f1],
    inputs={'image': image, 'apply_dropout': apply_dropout},
    outputs={'prob': prob},
    model_input_path=generator.model_directory + 'model-1-depth',
    model_output_path=generator.model_directory + 'model-1-depth'
)
model.print_only_on_best_model = True

model.fit(
    train_iterator, train_loader.batches_per_epoch, test_iterator,
    epochs=8000,
    early_stopping_patience=5000,
    load=False,
    save=True,
    export=False,
)
# Out:
# Epoch	Time[s]	Train Accuracy	Test Loss	Accuracy	Precision	Recall		F1
#    -1	0.00	-1.0000		0.3396		0.4946		0.6538		0.1683		0.4146
#     0	0.37	0.5000		0.3392		0.5978		0.6446		0.3861		0.5685
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#     1	0.66	0.4922		0.3388		0.5978		0.6435		0.4587		0.5955
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#     2	0.82	0.5625		0.3383		0.5978		0.6431		0.4950		0.6068
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#     3	0.97	0.4922		0.3379		0.5978		0.6429		0.5168		0.6130
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#     4	1.12	0.5859		0.3375		0.5978		0.6427		0.5314		0.6169
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#     5	1.28	0.5312		0.3370		0.5978		0.6426		0.5417		0.6195
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#     6	1.43	0.5625		0.3366		0.5978		0.6425		0.5495		0.6215
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#     7	1.58	0.5781		0.3363		0.5978		0.6425		0.5556		0.6230
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#     8	1.73	0.6328		0.3360		0.5978		0.6425		0.5604		0.6242
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#     9	1.90	0.6094		0.3357		0.5978		0.6424		0.5644		0.6251
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    10	2.05	0.4688		0.3354		0.5978		0.6424		0.5677		0.6259
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    11	2.22	0.6406		0.3352		0.5978		0.6424		0.5704		0.6266
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    12	2.39	0.5547		0.3350		0.5978		0.6423		0.5728		0.6271
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    13	2.55	0.6328		0.3347		0.5978		0.6423		0.5749		0.6276
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    14	2.71	0.5781		0.3346		0.6576		0.6485		0.5730		0.6318
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    15	2.86	0.5547		0.3344		0.4674		0.6490		0.5416		0.6242
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    16	3.02	0.6641		0.3343		0.4511		0.6490		0.5116		0.6159
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    17	3.17	0.6719		0.3341		0.4511		0.6490		0.4846		0.6078
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    18	3.32	0.6797		0.3339		0.4511		0.6490		0.4604		0.5998
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    19	3.48	0.6875		0.3337		0.4511		0.6490		0.4385		0.5921
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    20	3.63	0.6406		0.3335		0.4511		0.6490		0.4185		0.5846
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    21	3.78	0.6797		0.3332		0.4511		0.6490		0.4003		0.5773
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    22	3.94	0.6641		0.3331		0.4511		0.6490		0.3837		0.5701
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    23	4.09	0.6719		0.3330		0.4511		0.6490		0.3683		0.5632
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    30	4.50	0.7031		0.3329		0.4511		0.6490		0.2877		0.5187
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    31	4.68	0.6641		0.3328		0.4511		0.6490		0.2790		0.5130
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    32	4.84	0.7266		0.3326		0.4511		0.6490		0.2708		0.5073
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    33	4.99	0.7031		0.3324		0.4511		0.6490		0.2631		0.5018
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    34	5.15	0.6797		0.3323		0.4511		0.6490		0.2558		0.4964
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    35	5.30	0.7812		0.3322		0.4511		0.6490		0.2489		0.4911
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    36	5.46	0.7344		0.3322		0.4511		0.6490		0.2423		0.4859
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    37	5.61	0.7500		0.3322		0.4511		0.6490		0.2361		0.4808
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    38	5.76	0.7656		0.3321		0.4511		0.6490		0.2302		0.4758
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    39	5.91	0.6797		0.3321		0.4511		0.6490		0.2246		0.4710
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    42	6.14	0.7969		0.3321		0.4511		0.6490		0.2093		0.4570
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    43	6.30	0.7188		0.3319		0.4511		0.6490		0.2046		0.4525
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    44	6.45	0.7266		0.3319		0.4511		0.6490		0.2002		0.4481
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    45	6.60	0.7812		0.3319		0.4511		0.6490		0.1959		0.4437
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    49	6.87	0.8203		0.3318		0.4511		0.6490		0.1805		0.4273
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    50	7.02	0.7422		0.3317		0.4511		0.6490		0.1771		0.4233
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    51	7.18	0.7578		0.3316		0.4511		0.6490		0.1737		0.4195
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    52	7.33	0.7656		0.3314		0.4511		0.6490		0.1705		0.4157
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    53	7.48	0.7578		0.3312		0.4511		0.6490		0.1674		0.4120
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    54	7.63	0.7500		0.3310		0.4511		0.6490		0.1644		0.4083
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    55	7.79	0.7422		0.3308		0.4511		0.6490		0.1615		0.4047
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    56	7.94	0.7812		0.3305		0.4511		0.6490		0.1588		0.4012
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    57	8.09	0.7969		0.3304		0.4511		0.6490		0.1561		0.3977
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    58	8.24	0.7734		0.3303		0.4511		0.6490		0.1535		0.3943
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    59	8.39	0.7812		0.3303		0.4511		0.6490		0.1509		0.3910
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    60	8.54	0.7656		0.3302		0.4511		0.6490		0.1485		0.3877
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    61	8.69	0.8281		0.3299		0.4511		0.6490		0.1462		0.3845
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    62	8.85	0.7891		0.3297		0.4511		0.6490		0.1439		0.3813
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    63	9.00	0.8125		0.3297		0.4511		0.6490		0.1417		0.3781
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    64	9.15	0.8203		0.3296		0.4511		0.6490		0.1395		0.3751
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    67	9.38	0.8047		0.3295		0.4457		0.6481		0.1334		0.3659
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    68	9.54	0.7969		0.3294		0.4457		0.6476		0.1315		0.3629
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    69	9.69	0.8281		0.3293		0.4457		0.6472		0.1297		0.3599
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    70	9.84	0.7891		0.3292		0.4457		0.6467		0.1279		0.3570
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    71	10.00	0.7734		0.3290		0.4457		0.6463		0.1261		0.3542
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    72	10.15	0.7812		0.3288		0.4457		0.6458		0.1244		0.3514
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    73	10.30	0.7812		0.3286		0.4457		0.6454		0.1228		0.3486
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    74	10.46	0.8047		0.3284		0.4402		0.6445		0.1212		0.3458
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    75	10.61	0.7734		0.3282		0.4457		0.6440		0.1196		0.3431
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    76	10.76	0.8203		0.3281		0.4457		0.6436		0.1181		0.3405
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    77	10.91	0.7969		0.3279		0.4402		0.6427		0.1166		0.3378
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    78	11.07	0.7969		0.3276		0.4402		0.6418		0.1151		0.3351
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    79	11.23	0.7891		0.3274		0.4511		0.6414		0.1139		0.3330
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    80	11.39	0.8047		0.3272		0.4565		0.6413		0.1129		0.3312
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    81	11.55	0.8281		0.3269		0.4565		0.6411		0.1119		0.3295
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    82	11.70	0.8281		0.3262		0.4620		0.6413		0.1110		0.3280
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    83	11.85	0.7891		0.3256		0.4620		0.6414		0.1102		0.3265
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    84	12.01	0.8125		0.3252		0.4620		0.6415		0.1094		0.3251
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    85	12.16	0.8125		0.3248		0.4620		0.6416		0.1086		0.3237
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    86	12.31	0.8125		0.3245		0.4674		0.6419		0.1079		0.3226
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    87	12.46	0.8047		0.3243		0.4674		0.6422		0.1072		0.3215
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    88	12.61	0.8047		0.3241		0.4674		0.6426		0.1066		0.3204
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    89	12.77	0.8047		0.3236		0.4728		0.6433		0.1060		0.3194
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    90	12.92	0.8281		0.3230		0.4728		0.6441		0.1054		0.3184
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    91	13.07	0.7891		0.3228		0.4674		0.6444		0.1048		0.3174
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    92	13.22	0.8125		0.3227		0.4674		0.6447		0.1042		0.3164
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    93	13.37	0.8203		0.3220		0.4674		0.6450		0.1036		0.3154
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    94	13.52	0.8125		0.3214		0.4674		0.6453		0.1030		0.3144
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    95	13.68	0.7812		0.3209		0.4783		0.6463		0.1026		0.3137
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    96	13.83	0.8516		0.3206		0.4728		0.6468		0.1021		0.3130
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    97	13.98	0.8438		0.3202		0.4783		0.6478		0.1017		0.3124
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    98	14.13	0.8203		0.3194		0.4783		0.6487		0.1013		0.3117
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#    99	14.28	0.8203		0.3189		0.4783		0.6496		0.1009		0.3111
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   100	14.43	0.8125		0.3181		0.4783		0.6505		0.1005		0.3105
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   101	14.58	0.8438		0.3171		0.4837		0.6517		0.1002		0.3101
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   102	14.74	0.8516		0.3167		0.4783		0.6524		0.0999		0.3097
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   103	14.89	0.8750		0.3159		0.4891		0.6535		0.0998		0.3097
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   104	15.05	0.8516		0.3140		0.5163		0.6557		0.1001		0.3108
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   105	15.20	0.8750		0.3130		0.5217		0.6580		0.1006		0.3121
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   106	15.36	0.8203		0.3105		0.5435		0.6613		0.1013		0.3141
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   107	15.51	0.8125		0.3092		0.5435		0.6645		0.1020		0.3160
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   108	15.66	0.8438		0.3090		0.5380		0.6674		0.1026		0.3177
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   109	15.81	0.8672		0.3067		0.5543		0.6709		0.1035		0.3200
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   110	15.96	0.8594		0.3052		0.5543		0.6741		0.1044		0.3223
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   111	16.12	0.8516		0.3024		0.5924		0.6785		0.1059		0.3260
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   112	16.27	0.8281		0.3014		0.6033		0.6832		0.1075		0.3299
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   113	16.42	0.8672		0.3003		0.6304		0.6885		0.1096		0.3348
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   114	16.57	0.8516		0.2968		0.6413		0.6934		0.1120		0.3402
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   115	16.73	0.8828		0.2960		0.6141		0.6978		0.1137		0.3442
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   116	16.88	0.8750		0.2937		0.6413		0.7030		0.1158		0.3490
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   117	17.03	0.8516		0.2923		0.6304		0.7077		0.1176		0.3533
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   118	17.19	0.8516		0.2918		0.6196		0.7120		0.1193		0.3571
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   119	17.34	0.8750		0.2894		0.6413		0.7164		0.1213		0.3617
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   121	17.53	0.8672		0.2860		0.6413		0.7239		0.1245		0.3688
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   123	17.72	0.8516		0.2832		0.6630		0.7321		0.1286		0.3776
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   124	17.87	0.8984		0.2796		0.7228		0.7369		0.1319		0.3843
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   127	18.10	0.8516		0.2737		0.6739		0.7472		0.1370		0.3952
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   135	18.53	0.8906		0.2657		0.6630		0.7665		0.1456		0.4137
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   136	18.68	0.8906		0.2614		0.6630		0.7695		0.1475		0.4174
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   139	18.91	0.8828		0.2542		0.7011		0.7783		0.1534		0.4288
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   142	19.14	0.8516		0.2534		0.7989		0.7876		0.1609		0.4427
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   143	19.29	0.8906		0.2452		0.7554		0.7910		0.1638		0.4480
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   147	19.57	0.9062		0.2452		0.7011		0.7994		0.1702		0.4597
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   150	19.80	0.8516		0.2411		0.7065		0.8057		0.1755		0.4690
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   161	20.35	0.8516		0.2314		0.7174		0.8213		0.1856		0.4874
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   168	20.74	0.8906		0.2307		0.7283		0.8313		0.1941		0.5018
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   169	20.89	0.8984		0.2271		0.7120		0.8327		0.1959		0.5047
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   182	21.52	0.9219		0.2172		0.7391		0.8465		0.2104		0.5275
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   185	21.75	0.9141		0.2045		0.7717		0.8485		0.2166		0.5358
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   193	22.17	0.8906		0.1999		0.7826		0.8546		0.2302		0.5540
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   202	22.63	0.8594		0.1959		0.7663		0.8605		0.2419		0.5693
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   212	23.14	0.9141		0.1954		0.7826		0.8614		0.2642		0.5932
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   214	23.33	0.9062		0.1934		0.8098		0.8616		0.2684		0.5975
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   215	23.49	0.9141		0.1932		0.7880		0.8619		0.2704		0.5996
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
#   235	24.38	0.9062		0.1904		0.7880		0.8597		0.3080		0.6330
# Model saved in file: /home/berscheid/Documents/data/cylinder-2/models/model-1-depth
